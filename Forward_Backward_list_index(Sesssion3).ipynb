# %% [markdown]
# <a href="https://colab.research.google.com/github/AkankshaB123/python/blob/main/Forward_Backward_list_index(Sesssion3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Session 3 Topics
# 1. Slicing in the Indexes - Simple - **[start(inclusive) : end(exclusive)]**
# 2. Forward indexing and backward indexing
# * l1 = [1, 2, 3, 4, 7, 8, 9]
# * FI =  0, 1, 2, 3, 4, 5, 6 (Forward-Indexing)
# * BI = -7,-6,-5,-4,-3,-2,-1 (Backward-Indexing) Business-usecase: Log files latest issue identification l1[-3]: last 3 latest records
#
# Note:
# 1. Function(Generalised for all) and Methods(Specific to one)
# * type() - Function, applicable to all compound data types(list, tuple, set, dict)
# * .append() - Method, applicable to list data type only
#
# 2. List creation
# l1 = list() Explicit list creation
# l2 = [] Implicit list creation
#
# 3. Default list and Access list
# [] - list
# obj[] - access list
#
# 4. Compound data type value starts from 0

# %% [markdown]
# ## Assignment 1
#
# l1 = [123, 456, 789, 455, 9876]
#
# * q1. Find the last 3 elements
# * q2. Find the central element (Assume odd numbered list)
# * q3. Find the length of the list and use it to get the 4th last element

# %%
#q1.
l1 = [123, 456, 789, 455, 9876]
l1[-3:]
# Out:
# [789, 455, 9876]

# %%
#q2.
l1[len(l1)//2] #central element is derived
# Out:
# 789

# %%
#q3. 4th last element
l1[len(l1)-4]
# Out:
# 456

# %%
len(l1) #l1 = [123, 456, 789, 455, 9876]
            #  0     1    2    3    4
# Out:
# 5

# %%
len(l1)-1
# Out:
# 4
