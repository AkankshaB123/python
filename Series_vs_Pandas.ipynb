# %% [markdown]
# <a href="https://colab.research.google.com/github/AkankshaB123/python/blob/main/Series_vs_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = [['0','Y','N'],['1','Y','Y'],['2','N','Y'],['3','Y','Y'],['4','N','N']]
df = pd.DataFrame(data, columns = ['product_id','low_fats','recyclable']).astype({'product_id': 'int64', 'low_fats':'category','recyclable':'category'})

# %%
type(df['product_id'])
# Out:
# pandas.core.series.Series

# %%
type(df[['product_id']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['product_id','low_fats']])
# Out:
# pandas.core.frame.DataFrame
